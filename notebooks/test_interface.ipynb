# %%
from sealer_interface import Sealer
from madsci.client import ResourceClient

# %%
resource_client = ResourceClient(resource_server_url="http://batman.cels.anl.gov:8004")

# %%
resource_client.query_resource(
    resource_name="a4s_sealer_carriage_template",
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 resource_client.query_resource(
#       2     resource_name="a4s_sealer_carriage_template",
#       3 )
#
# File ~/workspace/a4s_sealer_module/.venv/lib/python3.12/site-packages/madsci/client/resource_client.py:449, in ResourceClient.query_resource(self, resource, resource_name, parent_id, resource_class, base_type, unique, multiple)
#     437 payload = ResourceGetQuery(
#     438     resource_id=resource_id,
#     439     resource_name=resource_name,
#    (...)
#     444     multiple=multiple,
#     445 ).model_dump(mode="json")
#     446 response = requests.post(
#     447     f"{self.resource_server_url}resource/query", json=payload, timeout=10
#     448 )
# --> 449 response.raise_for_status()
#     450 response_json = response.json()
#     451 if isinstance(response_json, list):
#
# ...
